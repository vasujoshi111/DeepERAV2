# %%
from utils import get_data_loader, train, test, train_losses, test_losses, train_acc, test_acc
from utils import visualize_data, plot_metrics
from model import get_train_parameters

# %%
# Define number of epochs and batch size
num_epochs = 20
batch_size = 512

# %%
train_loader, test_loader = get_data_loader(batch_size)

# %%
visualize_data(train_loader)

# %%
model, device, optimizer, scheduler, criterion = get_train_parameters()
# Out:
# Running on cuda
# Adjusting learning rate of group 0 to 1.0000e-02.

# %%
#Iterate over each epoch and calculate test accuracy after each epoch
for epoch in range(1, num_epochs+1):
  print(f'Epoch {epoch}')
  train(model, device, train_loader, optimizer, criterion)
  test(model, device, test_loader, criterion)
  scheduler.step()
# Out:
# Epoch 1
# Train: Loss=0.4577 Batch_id=117 Accuracy=47.96: 100%|██████████| 118/118 [00:22<00:00,  5.25it/s]
# Test set: Average loss: 0.0005, Accuracy: 9245/10000 (92.45%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 2
# Train: Loss=0.1364 Batch_id=117 Accuracy=93.81: 100%|██████████| 118/118 [00:20<00:00,  5.72it/s]
# Test set: Average loss: 0.0002, Accuracy: 9737/10000 (97.37%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 3
# Train: Loss=0.0968 Batch_id=117 Accuracy=96.20: 100%|██████████| 118/118 [00:21<00:00,  5.53it/s]
# Test set: Average loss: 0.0001, Accuracy: 9800/10000 (98.00%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 4
# Train: Loss=0.1226 Batch_id=117 Accuracy=97.14: 100%|██████████| 118/118 [00:21<00:00,  5.49it/s]
# Test set: Average loss: 0.0001, Accuracy: 9845/10000 (98.45%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 5
# Train: Loss=0.0125 Batch_id=117 Accuracy=97.56: 100%|██████████| 118/118 [00:21<00:00,  5.50it/s]
# Test set: Average loss: 0.0001, Accuracy: 9856/10000 (98.56%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 6
# Train: Loss=0.1257 Batch_id=117 Accuracy=97.81: 100%|██████████| 118/118 [00:21<00:00,  5.49it/s]
# Test set: Average loss: 0.0001, Accuracy: 9842/10000 (98.42%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 7
# Train: Loss=0.0298 Batch_id=117 Accuracy=97.89: 100%|██████████| 118/118 [00:20<00:00,  5.79it/s]
# Test set: Average loss: 0.0001, Accuracy: 9859/10000 (98.59%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 8
# Train: Loss=0.0464 Batch_id=117 Accuracy=98.17: 100%|██████████| 118/118 [00:20<00:00,  5.63it/s]
# Test set: Average loss: 0.0001, Accuracy: 9883/10000 (98.83%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 9
# Train: Loss=0.0846 Batch_id=117 Accuracy=98.31: 100%|██████████| 118/118 [00:21<00:00,  5.53it/s]
# Test set: Average loss: 0.0001, Accuracy: 9894/10000 (98.94%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 10
# Train: Loss=0.0899 Batch_id=117 Accuracy=98.42: 100%|██████████| 118/118 [00:21<00:00,  5.38it/s]
# Test set: Average loss: 0.0001, Accuracy: 9897/10000 (98.97%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 11
# Train: Loss=0.0203 Batch_id=117 Accuracy=98.56: 100%|██████████| 118/118 [00:21<00:00,  5.41it/s]
# Test set: Average loss: 0.0001, Accuracy: 9903/10000 (99.03%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 12
# Train: Loss=0.0625 Batch_id=117 Accuracy=98.64: 100%|██████████| 118/118 [00:21<00:00,  5.52it/s]
# Test set: Average loss: 0.0001, Accuracy: 9901/10000 (99.01%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 13
# Train: Loss=0.0382 Batch_id=117 Accuracy=98.74: 100%|██████████| 118/118 [00:20<00:00,  5.64it/s]
# Test set: Average loss: 0.0001, Accuracy: 9909/10000 (99.09%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 14
# Train: Loss=0.0106 Batch_id=117 Accuracy=98.78: 100%|██████████| 118/118 [00:21<00:00,  5.61it/s]
# Test set: Average loss: 0.0000, Accuracy: 9916/10000 (99.16%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 15
# Train: Loss=0.0138 Batch_id=117 Accuracy=98.80: 100%|██████████| 118/118 [00:21<00:00,  5.39it/s]
# Test set: Average loss: 0.0000, Accuracy: 9924/10000 (99.24%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 16
# Train: Loss=0.0253 Batch_id=117 Accuracy=99.15: 100%|██████████| 118/118 [00:21<00:00,  5.41it/s]
# Test set: Average loss: 0.0000, Accuracy: 9928/10000 (99.28%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 17
# Train: Loss=0.0129 Batch_id=117 Accuracy=99.13: 100%|██████████| 118/118 [00:21<00:00,  5.42it/s]
# Test set: Average loss: 0.0000, Accuracy: 9926/10000 (99.26%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 18
# Train: Loss=0.0133 Batch_id=117 Accuracy=99.21: 100%|██████████| 118/118 [00:21<00:00,  5.40it/s]
# Test set: Average loss: 0.0000, Accuracy: 9926/10000 (99.26%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 19
# Train: Loss=0.0348 Batch_id=117 Accuracy=99.17: 100%|██████████| 118/118 [00:21<00:00,  5.43it/s]
# Test set: Average loss: 0.0000, Accuracy: 9928/10000 (99.28%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 20
# Train: Loss=0.0091 Batch_id=117 Accuracy=99.15: 100%|██████████| 118/118 [00:20<00:00,  5.73it/s]
# Test set: Average loss: 0.0000, Accuracy: 9931/10000 (99.31%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.

# %%
plot_metrics(train_losses, train_acc, test_losses, test_acc)

# %%
# !pip install torchsummary
from torchsummary import summary
summary(model, input_size=(1, 28, 28))
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.10/dist-packages (1.5.1)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 26, 26]             320
#             Conv2d-2           [-1, 64, 24, 24]          18,496
#             Conv2d-3          [-1, 128, 10, 10]          73,856
#             Conv2d-4            [-1, 256, 8, 8]         295,168
#             Linear-5                   [-1, 50]         204,850
#             Linear-6                   [-1, 10]             510
# ================================================================
# Total params: 593,200
# Trainable params: 593,200
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.67
# Params size (MB): 2.26
# Estimated Total Size (MB): 2.94
# ----------------------------------------------------------------
